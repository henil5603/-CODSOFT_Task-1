# %% [markdown]
# # Task-1

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score

# %%
data = pd.read_csv('C:/Users/Admin/Desktop/CodSoft/imdb_top_2000_movies.csv')
data
# Out:
#                  Movie Name Release Year  Duration  IMDB Rating  Metascore  \
# 0             The Godfather         1972       175          9.2      100.0
# 1     The Godfather Part II         1974       202          9.0       90.0
# 2           Ordinary People         1980       124          7.7       86.0
# 3        Lawrence of Arabia         1962       218          8.3      100.0
# 4                Straw Dogs         1971       113          7.4       73.0
# ...                     ...          ...       ...          ...        ...
# 1995     The Young Victoria         2009       105          7.2       64.0
# 1996            Tooth Fairy       I 2010       101          5.0       36.0
# 1997         The Informant!         2009       108          6.5       66.0
# 1998        Youth in Revolt         2009        90          6.4       63.0
# 1999             Quarantine         2008        89          6.0       53.0
#
#           Votes                        Genre              Director  \
# 0     2,002,655                 Crime, Drama  Francis Ford Coppola
# 1     1,358,608                 Crime, Drama  Francis Ford Coppola
# 2        56,476                        Drama        Robert Redford
# 3       313,044  Adventure, Biography, Drama            David Lean
# 4        64,331       Crime, Drama, Thriller         Sam Peckinpah
# ...         ...                          ...                   ...
# 1995     66,235    Biography, Drama, History      Jean-Marc Vallée
# 1996     49,527      Comedy, Family, Fantasy       Michael Lembeck
# 1997     67,318     Biography, Comedy, Crime     Steven Soderbergh
# 1998     75,956       Comedy, Drama, Romance         Miguel Arteta
# 1999     77,075     Horror, Sci-Fi, Thriller     John Erick Dowdle
#
#                     Cast     Gross
# 0          Marlon Brando  $134.97M
# 1              Al Pacino   $57.30M
# 2      Donald Sutherland   $54.80M
# 3          Peter O'Toole   $44.82M
# 4         Dustin Hoffman       NaN
# ...                  ...       ...
# 1995         Emily Blunt   $11.00M
# 1996      Dwayne Johnson   $60.02M
# 1997          Matt Damon   $33.31M
# 1998        Michael Cera   $15.28M
# 1999  Jennifer Carpenter   $31.69M
#
# [2000 rows x 10 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(data['Movie Name'], data['Genre'], test_size=0.2, random_state=42)

# %%
X_train
# Out:
# 968                         Sexy Beast
# 240     Invasion of the Body Snatchers
# 819                                 Go
# 692           Clear and Present Danger
# 420                            Rocky V
#                      ...
# 1130                   Men in Black II
# 1294                     The New World
# 860                  Never Been Kissed
# 1459                    Broken Flowers
# 1126                          Thirteen
# Name: Movie Name, Length: 1600, dtype: object

# %%
X_test
# Out:
# 1860                     I Spit on Your Grave
# 353                   Pee-wee's Big Adventure
# 1333                      Final Destination 3
# 905                               BASEketball
# 1289                            Der Untergang
#                         ...
# 965                              The Avengers
# 1284    The Fast and the Furious: Tokyo Drift
# 1739                              Speed Racer
# 261                    Little Shop of Horrors
# 535                        The Usual Suspects
# Name: Movie Name, Length: 400, dtype: object

# %%
y_test
# Out:
# 1860             Horror, Thriller
# 353     Adventure, Comedy, Family
# 1333             Horror, Thriller
# 905                 Comedy, Sport
# 1289    Biography, Drama, History
#                   ...
# 965     Action, Adventure, Sci-Fi
# 1284      Action, Crime, Thriller
# 1739    Action, Adventure, Comedy
# 261       Comedy, Horror, Musical
# 535         Crime, Drama, Mystery
# Name: Genre, Length: 400, dtype: object

# %%
y_train
# Out:
# 968        Crime, Drama, Thriller
# 240                Horror, Sci-Fi
# 819                 Comedy, Crime
# 692          Action, Crime, Drama
# 420                  Drama, Sport
#                   ...
# 1130    Action, Adventure, Comedy
# 1294    Biography, Drama, History
# 860        Comedy, Drama, Romance
# 1459       Comedy, Drama, Mystery
# 1126                        Drama
# Name: Genre, Length: 1600, dtype: object

# %%
tfidf_vectorizer = TfidfVectorizer(stop_words='english')
tfidf_vectorizer
# Out:
# TfidfVectorizer(stop_words='english')

# %%
X_train_tfidf = tfidf_vectorizer.fit_transform(X_train)
X_train_tfidf
# Out:
# <1600x2050 sparse matrix of type '<class 'numpy.float64'>'
# 	with 3071 stored elements in Compressed Sparse Row format>

# %%
X_test_tfidf = tfidf_vectorizer.transform(X_test)
X_test_tfidf
# Out:
# <400x2050 sparse matrix of type '<class 'numpy.float64'>'
# 	with 369 stored elements in Compressed Sparse Row format>

# %%
classifier = LogisticRegression(max_iter=1000)
classifier.fit(X_train_tfidf, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
y_pred = classifier.predict(X_test_tfidf)
y_pred
# Out:
# array(['Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Horror, Thriller', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance', 'Comedy',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance', 'Comedy',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Action, Adventure, Sci-Fi',
#        'Comedy, Drama, Romance', 'Action, Adventure, Sci-Fi',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance', 'Comedy',
#        'Comedy, Drama, Romance', 'Action, Adventure, Sci-Fi',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance', 'Comedy',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy', 'Comedy, Drama, Romance',
#        'Drama', 'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Action, Adventure, Sci-Fi',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance', 'Drama',
#        'Comedy, Drama, Romance', 'Comedy', 'Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Action, Crime, Drama',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Drama', 'Comedy, Drama, Romance',
#        'Action, Adventure, Sci-Fi', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Animation, Adventure, Comedy',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy', 'Comedy',
#        'Comedy, Drama, Romance', 'Comedy', 'Comedy, Drama, Romance',
#        'Comedy', 'Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Animation, Adventure, Comedy',
#        'Action, Adventure, Sci-Fi', 'Action, Adventure, Comedy',
#        'Comedy, Drama, Romance', 'Action, Adventure, Sci-Fi',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance', 'Comedy',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Action, Adventure, Sci-Fi', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Action, Adventure, Comedy', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance', 'Comedy',
#        'Comedy, Drama, Romance', 'Animation, Adventure, Comedy',
#        'Comedy, Drama, Romance', 'Comedy', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Action, Adventure, Thriller', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Action, Adventure, Sci-Fi', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Action, Adventure, Sci-Fi', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Action, Adventure, Sci-Fi',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance', 'Drama',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Action, Adventure, Thriller',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Animation, Adventure, Comedy',
#        'Comedy, Drama, Romance', 'Action, Adventure, Fantasy',
#        'Comedy, Drama, Romance', 'Action, Crime, Thriller',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Drama, Romance', 'Comedy, Drama, Romance', 'Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Drama', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Animation, Adventure, Comedy',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy', 'Drama',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Animation, Adventure, Comedy', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Drama, Sport', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Animation, Adventure, Comedy',
#        'Action, Adventure, Comedy', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance', 'Comedy',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Action, Adventure, Thriller', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Romance', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Action, Adventure, Fantasy', 'Comedy, Drama, Romance',
#        'Action, Adventure, Thriller', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Action, Adventure, Sci-Fi',
#        'Comedy, Drama, Romance', 'Comedy, Drama, Romance',
#        'Action, Adventure, Drama', 'Comedy, Drama, Romance',
#        'Comedy, Drama, Romance', 'Action, Crime, Thriller',
#        'Action, Adventure, Thriller', 'Drama, Romance',
#        'Comedy, Drama, Romance'], dtype=object)

# %%
print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.0875

# %%
print(classification_report(y_test, y_pred))
# Out:
#                                precision    recall  f1-score   support
#
#             Action, Adventure       0.00      0.00      0.00         1
#     Action, Adventure, Comedy       0.67      0.13      0.22        15
#      Action, Adventure, Drama       0.00      0.00      0.00         6
#     Action, Adventure, Family       0.00      0.00      0.00         1
#    Action, Adventure, Fantasy       1.00      0.25      0.40         8
#    Action, Adventure, Mystery       0.00      0.00      0.00         1
#     Action, Adventure, Sci-Fi       0.33      0.29      0.31        14
#   Action, Adventure, Thriller       0.20      0.12      0.15         8
#                Action, Comedy       0.00      0.00      0.00         3
#         Action, Comedy, Crime       0.00      0.00      0.00         1
#       Action, Comedy, Fantasy       0.00      0.00      0.00         3
#        Action, Comedy, Sci-Fi       0.00      0.00      0.00         3
#      Action, Comedy, Thriller       0.00      0.00      0.00         1
#          Action, Crime, Drama       0.00      0.00      0.00         9
#        Action, Crime, Romance       0.00      0.00      0.00         1
#         Action, Crime, Sci-Fi       0.00      0.00      0.00         2
#       Action, Crime, Thriller       1.00      0.22      0.36         9
#                 Action, Drama       0.00      0.00      0.00         1
#         Action, Drama, Family       0.00      0.00      0.00         1
#        Action, Drama, History       0.00      0.00      0.00         2
#          Action, Drama, Music       0.00      0.00      0.00         1
#         Action, Drama, Sci-Fi       0.00      0.00      0.00         2
#          Action, Drama, Sport       0.00      0.00      0.00         4
#       Action, Drama, Thriller       0.00      0.00      0.00         4
#        Action, Horror, Sci-Fi       0.00      0.00      0.00         3
#      Action, Horror, Thriller       0.00      0.00      0.00         1
#       Action, Mystery, Sci-Fi       0.00      0.00      0.00         1
#     Action, Mystery, Thriller       0.00      0.00      0.00         1
#                Action, Sci-Fi       0.00      0.00      0.00         2
#      Action, Sci-Fi, Thriller       0.00      0.00      0.00         5
#              Action, Thriller       0.00      0.00      0.00         1
#   Adventure, Biography, Drama       0.00      0.00      0.00         1
#      Adventure, Comedy, Drama       0.00      0.00      0.00         1
#     Adventure, Comedy, Family       0.00      0.00      0.00         6
#    Adventure, Comedy, Fantasy       0.00      0.00      0.00         2
#      Adventure, Comedy, Music       0.00      0.00      0.00         2
#    Adventure, Comedy, Musical       0.00      0.00      0.00         1
#     Adventure, Comedy, Sci-Fi       0.00      0.00      0.00         2
#       Adventure, Crime, Drama       0.00      0.00      0.00         1
#      Adventure, Drama, Family       0.00      0.00      0.00         2
#      Adventure, Drama, Sci-Fi       0.00      0.00      0.00         2
#    Adventure, Drama, Thriller       0.00      0.00      0.00         2
#     Adventure, Drama, Western       0.00      0.00      0.00         2
#    Adventure, Family, Fantasy       0.00      0.00      0.00         4
#     Adventure, Family, Sci-Fi       0.00      0.00      0.00         1
#             Adventure, Horror       0.00      0.00      0.00         1
#  Animation, Action, Adventure       0.00      0.00      0.00         2
#  Animation, Adventure, Comedy       0.43      0.38      0.40         8
#   Animation, Adventure, Drama       0.00      0.00      0.00         1
#  Animation, Adventure, Family       0.00      0.00      0.00         2
#      Animation, Drama, Family       0.00      0.00      0.00         1
#    Animation, Family, Fantasy       0.00      0.00      0.00         2
#       Biography, Crime, Drama       0.00      0.00      0.00         2
#              Biography, Drama       0.00      0.00      0.00         8
#     Biography, Drama, History       0.00      0.00      0.00         2
#       Biography, Drama, Music       0.00      0.00      0.00         4
#     Biography, Drama, Romance       0.00      0.00      0.00         2
#       Biography, Drama, Sport       0.00      0.00      0.00         1
#    Biography, Drama, Thriller       0.00      0.00      0.00         1
#         Biography, Drama, War       0.00      0.00      0.00         2
#                        Comedy       0.17      0.40      0.24        10
#                 Comedy, Crime       0.00      0.00      0.00         2
#          Comedy, Crime, Drama       0.00      0.00      0.00         1
#        Comedy, Crime, Fantasy       0.00      0.00      0.00         1
#        Comedy, Crime, Romance       0.00      0.00      0.00         1
#                 Comedy, Drama       1.00      0.09      0.17        11
#         Comedy, Drama, Family       0.00      0.00      0.00         3
#        Comedy, Drama, Fantasy       0.00      0.00      0.00         3
#          Comedy, Drama, Music       0.00      0.00      0.00         2
#        Comedy, Drama, Romance       0.04      0.93      0.08        15
#            Comedy, Drama, War       0.00      0.00      0.00         1
#                Comedy, Family       0.00      0.00      0.00         1
#       Comedy, Family, Fantasy       0.00      0.00      0.00         2
#         Comedy, Family, Music       0.00      0.00      0.00         1
#        Comedy, Family, Sci-Fi       0.00      0.00      0.00         1
#         Comedy, Family, Sport       0.00      0.00      0.00         3
#               Comedy, Fantasy       0.00      0.00      0.00         3
#      Comedy, Fantasy, Romance       0.00      0.00      0.00         1
#      Comedy, History, Musical       0.00      0.00      0.00         1
#                Comedy, Horror       0.00      0.00      0.00         3
#       Comedy, Horror, Musical       0.00      0.00      0.00         2
#     Comedy, Mystery, Thriller       0.00      0.00      0.00         1
#               Comedy, Romance       0.00      0.00      0.00        15
#                 Comedy, Sport       0.00      0.00      0.00         3
#               Comedy, Western       0.00      0.00      0.00         2
#                  Crime, Drama       0.00      0.00      0.00         3
#       Crime, Drama, Film-Noir       0.00      0.00      0.00         1
#         Crime, Drama, Musical       0.00      0.00      0.00         1
#         Crime, Drama, Mystery       0.00      0.00      0.00         9
#         Crime, Drama, Romance       0.00      0.00      0.00         1
#           Crime, Drama, Sport       0.00      0.00      0.00         1
#        Crime, Drama, Thriller       0.00      0.00      0.00        12
#     Crime, Film-Noir, Mystery       0.00      0.00      0.00         1
#        Crime, Mystery, Sci-Fi       0.00      0.00      0.00         1
#      Crime, Mystery, Thriller       0.00      0.00      0.00         2
#               Crime, Thriller       0.00      0.00      0.00         3
# Documentary, Biography, Crime       0.00      0.00      0.00         1
#                         Drama       0.00      0.00      0.00        13
#        Drama, Family, Musical       0.00      0.00      0.00         1
#        Drama, Family, Romance       0.00      0.00      0.00         1
#                Drama, Fantasy       0.00      0.00      0.00         1
#        Drama, Fantasy, Horror       0.00      0.00      0.00         3
#       Drama, Fantasy, Mystery       0.00      0.00      0.00         3
#       Drama, Fantasy, Romance       0.00      0.00      0.00         3
#              Drama, Film-Noir       0.00      0.00      0.00         1
#           Drama, History, War       0.00      0.00      0.00         1
#        Drama, Horror, Mystery       0.00      0.00      0.00         2
#         Drama, Horror, Sci-Fi       0.00      0.00      0.00         3
#                  Drama, Music       0.00      0.00      0.00         1
#         Drama, Music, Romance       0.00      0.00      0.00         3
#                Drama, Musical       0.00      0.00      0.00         1
#       Drama, Musical, Romance       0.00      0.00      0.00         1
#       Drama, Mystery, Romance       0.00      0.00      0.00         1
#        Drama, Mystery, Sci-Fi       0.00      0.00      0.00         4
#      Drama, Mystery, Thriller       0.00      0.00      0.00         5
#                Drama, Romance       0.08      0.11      0.10         9
#        Drama, Romance, Sci-Fi       0.00      0.00      0.00         1
#         Drama, Romance, Sport       0.00      0.00      0.00         2
#      Drama, Romance, Thriller       0.00      0.00      0.00         1
#           Drama, Romance, War       0.00      0.00      0.00         2
#       Drama, Sci-Fi, Thriller       0.00      0.00      0.00         1
#                  Drama, Sport       0.00      0.00      0.00         0
#               Drama, Thriller       0.00      0.00      0.00         2
#                    Drama, War       0.00      0.00      0.00         1
#                Drama, Western       0.00      0.00      0.00         1
#                        Horror       0.00      0.00      0.00         4
#               Horror, Mystery       0.00      0.00      0.00         5
#     Horror, Mystery, Thriller       0.00      0.00      0.00         5
#      Horror, Sci-Fi, Thriller       0.00      0.00      0.00         2
#              Horror, Thriller       1.00      0.17      0.29         6
#             Mystery, Thriller       0.00      0.00      0.00         1
#                      Thriller       0.00      0.00      0.00         1
#
#                      accuracy                           0.09       400
#                     macro avg       0.04      0.02      0.02       400
#                  weighted avg       0.14      0.09      0.07       400
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\Admin\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1469: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
